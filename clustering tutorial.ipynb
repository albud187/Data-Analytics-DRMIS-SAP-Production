# %% [markdown]
# clustering for mixed data types - https://www.youtube.com/watch?v=8eATPLDJ0NQ

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

import sklearn

from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import scale

import kmodes
from kmodes.kprototypes import KPrototypes

import sklearn.metrics as sm
from sklearn import datasets
from sklearn.metrics import confusion_matrix, classification_report

# %%
marketing_df = pd.read_csv('https://raw.githubusercontent.com/srivatsan88/YouTubeLI/master/dataset/marketing_cva_f.csv')
marketing_df.to_csv('clustering tutorial_data.csv')

# %%
marketing_df = marketing_df.drop(['Customer', 'Vehicle_Class', 'avg_vehicle_age', 'months_last_claim', 'Total_Claim_Amount'], axis = 1)

# %%
marketing_df
# Out:
#            State           CLV  Coverage  Income  loc_type  monthly_premium  \
# 0     Washington   2763.519279     Basic   56274  Suburban               69
# 1         Nevada  12887.431650   Premium   48767  Suburban              108
# 2     Washington   2813.692575     Basic   43836     Rural               73
# 3         Oregon   8256.297800     Basic   62902     Rural               69
# 4         Oregon   5380.898636     Basic   55350  Suburban               67
# ...          ...           ...       ...     ...       ...              ...
# 6812  California   5032.165498     Basic   66367  Suburban               64
# 6813  California   4100.398533   Premium   47761  Suburban              104
# 6814  California  23405.987980     Basic   71941     Urban               73
# 6815  California   3096.511217  Extended   21604  Suburban               79
# 6816  California   7524.442436  Extended   21941  Suburban               96
#
#       Months_Since_Policy_Inception
# 0                                 5
# 1                                38
# 2                                44
# 3                                94
# 4                                13
# ...                             ...
# 6812                             48
# 6813                             58
# 6814                             89
# 6815                             28
# 6816                              3
#
# [6817 rows x 7 columns]

# %%
mark_array = marketing_df.values

# %%
mark_array
# Out:
# array([['Washington', 2763.519279, 'Basic', ..., 'Suburban', 69, 5],
#        ['Nevada', 12887.43165, 'Premium', ..., 'Suburban', 108, 38],
#        ['Washington', 2813.692575, 'Basic', ..., 'Rural', 73, 44],
#        ...,
#        ['California', 23405.98798, 'Basic', ..., 'Urban', 73, 89],
#        ['California', 3096.511217, 'Extended', ..., 'Suburban', 79, 28],
#        ['California', 7524.442436, 'Extended', ..., 'Suburban', 96, 3]],
#       dtype=object)

# %%
mark_array[:, 1] = mark_array[:, 1].astype(float)
mark_array[:, 3] = mark_array[:, 3].astype(float)
mark_array[:, 5] = mark_array[:, 5].astype(float)
mark_array[:, 6] = mark_array[:, 6].astype(float)

# %%
mark_array
# Out:
# array([['Washington', 2763.519279, 'Basic', ..., 'Suburban', 69.0, 5.0],
#        ['Nevada', 12887.43165, 'Premium', ..., 'Suburban', 108.0, 38.0],
#        ['Washington', 2813.692575, 'Basic', ..., 'Rural', 73.0, 44.0],
#        ...,
#        ['California', 23405.98798, 'Basic', ..., 'Urban', 73.0, 89.0],
#        ['California', 3096.511217, 'Extended', ..., 'Suburban', 79.0,
#         28.0],
#        ['California', 7524.442436, 'Extended', ..., 'Suburban', 96.0,
#         3.0]], dtype=object)

# %%
kproto = KPrototypes(n_clusters = 3, verbose = 2, max_iter = 20)
clusters = kproto.fit_predict(mark_array, categorical = [0, 2, 4])
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 1, iteration: 1/20, moves: 294, ncost: 786191417664.713
# Run: 1, iteration: 2/20, moves: 58, ncost: 785662723324.5215
# Run: 1, iteration: 3/20, moves: 27, ncost: 785566620155.1418
# Run: 1, iteration: 4/20, moves: 10, ncost: 785551468522.3026
# Run: 1, iteration: 5/20, moves: 6, ncost: 785546422486.777
# Run: 1, iteration: 6/20, moves: 2, ncost: 785545634415.1552
# Run: 1, iteration: 7/20, moves: 0, ncost: 785545634415.1552
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 2, iteration: 1/20, moves: 373, ncost: 792947402881.1442
# Run: 2, iteration: 2/20, moves: 191, ncost: 787645043356.4779
# Run: 2, iteration: 3/20, moves: 86, ncost: 786447784903.568
# Run: 2, iteration: 4/20, moves: 59, ncost: 785945968414.2338
# Run: 2, iteration: 5/20, moves: 45, ncost: 785708436066.9501
# Run: 2, iteration: 6/20, moves: 20, ncost: 785655117685.776
# Run: 2, iteration: 7/20, moves: 15, ncost: 785613961116.1893
# Run: 2, iteration: 8/20, moves: 15, ncost: 785587014534.5707
# Run: 2, iteration: 9/20, moves: 6, ncost: 785580196116.0236
# Run: 2, iteration: 10/20, moves: 4, ncost: 785577307058.1283
# Run: 2, iteration: 11/20, moves: 4, ncost: 785574087818.505
# Run: 2, iteration: 12/20, moves: 3, ncost: 785572843787.396
# Run: 2, iteration: 13/20, moves: 0, ncost: 785572843787.396
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 3, iteration: 1/20, moves: 816, ncost: 852700063123.299
# Run: 3, iteration: 2/20, moves: 552, ncost: 809913025433.1704
# Run: 3, iteration: 3/20, moves: 380, ncost: 792958550142.4271
# Run: 3, iteration: 4/20, moves: 203, ncost: 788059335060.9534
# Run: 3, iteration: 5/20, moves: 111, ncost: 786496091108.3053
# Run: 3, iteration: 6/20, moves: 79, ncost: 785739359865.1387
# Run: 3, iteration: 7/20, moves: 39, ncost: 785571996335.9271
# Run: 3, iteration: 8/20, moves: 11, ncost: 785552822475.9594
# Run: 3, iteration: 9/20, moves: 6, ncost: 785548092552.7046
# Run: 3, iteration: 10/20, moves: 4, ncost: 785545634415.1554
# Run: 3, iteration: 11/20, moves: 0, ncost: 785545634415.1554
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 4, iteration: 1/20, moves: 1296, ncost: 896370516927.7231
# Run: 4, iteration: 2/20, moves: 719, ncost: 829345112417.0548
# Run: 4, iteration: 3/20, moves: 480, ncost: 800353496026.3496
# Run: 4, iteration: 4/20, moves: 287, ncost: 790522490692.7234
# Run: 4, iteration: 5/20, moves: 159, ncost: 787331663278.2163
# Run: 4, iteration: 6/20, moves: 93, ncost: 786183724462.9103
# Run: 4, iteration: 7/20, moves: 67, ncost: 785655956320.5771
# Run: 4, iteration: 8/20, moves: 26, ncost: 785566620155.142
# Run: 4, iteration: 9/20, moves: 10, ncost: 785551468522.303
# Run: 4, iteration: 10/20, moves: 6, ncost: 785546422486.7771
# Run: 4, iteration: 11/20, moves: 2, ncost: 785545634415.1553
# Run: 4, iteration: 12/20, moves: 0, ncost: 785545634415.1553
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 5, iteration: 1/20, moves: 1292, ncost: 791170231523.1644
# Run: 5, iteration: 2/20, moves: 320, ncost: 785731417330.2385
# Run: 5, iteration: 3/20, moves: 42, ncost: 785564139538.9409
# Run: 5, iteration: 4/20, moves: 9, ncost: 785551468522.3025
# Run: 5, iteration: 5/20, moves: 6, ncost: 785546422486.7771
# Run: 5, iteration: 6/20, moves: 2, ncost: 785545634415.1553
# Run: 5, iteration: 7/20, moves: 0, ncost: 785545634415.1553
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 6, iteration: 1/20, moves: 840, ncost: 786407047297.6582
# Run: 6, iteration: 2/20, moves: 135, ncost: 785592262411.1874
# Run: 6, iteration: 3/20, moves: 22, ncost: 785572843787.3956
# Run: 6, iteration: 4/20, moves: 0, ncost: 785572843787.3956
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 7, iteration: 1/20, moves: 1352, ncost: 950025154350.4193
# Run: 7, iteration: 2/20, moves: 946, ncost: 849278524957.5746
# Run: 7, iteration: 3/20, moves: 582, ncost: 807536973657.52
# Run: 7, iteration: 4/20, moves: 369, ncost: 792090711871.4281
# Run: 7, iteration: 5/20, moves: 186, ncost: 787855981611.7162
# Run: 7, iteration: 6/20, moves: 105, ncost: 786426844156.4158
# Run: 7, iteration: 7/20, moves: 74, ncost: 785733314562.7208
# Run: 7, iteration: 8/20, moves: 38, ncost: 785571996335.9274
# Run: 7, iteration: 9/20, moves: 11, ncost: 785552822475.9586
# Run: 7, iteration: 10/20, moves: 6, ncost: 785548092552.7048
# Run: 7, iteration: 11/20, moves: 4, ncost: 785545634415.1555
# Run: 7, iteration: 12/20, moves: 0, ncost: 785545634415.1555
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 8, iteration: 1/20, moves: 747, ncost: 809638814752.4982
# Run: 8, iteration: 2/20, moves: 364, ncost: 792430653643.8655
# Run: 8, iteration: 3/20, moves: 194, ncost: 787485045179.4767
# Run: 8, iteration: 4/20, moves: 84, ncost: 786362335777.2682
# Run: 8, iteration: 5/20, moves: 58, ncost: 785915689176.1141
# Run: 8, iteration: 6/20, moves: 42, ncost: 785698684485.5094
# Run: 8, iteration: 7/20, moves: 17, ncost: 785655117685.7758
# Run: 8, iteration: 8/20, moves: 15, ncost: 785613961116.1897
# Run: 8, iteration: 9/20, moves: 15, ncost: 785587014534.5714
# Run: 8, iteration: 10/20, moves: 6, ncost: 785580196116.0236
# Run: 8, iteration: 11/20, moves: 4, ncost: 785577307058.1284
# Run: 8, iteration: 12/20, moves: 4, ncost: 785574087818.5055
# Run: 8, iteration: 13/20, moves: 3, ncost: 785572843787.3959
# Run: 8, iteration: 14/20, moves: 0, ncost: 785572843787.3959
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 9, iteration: 1/20, moves: 483, ncost: 812717542420.0155
# Run: 9, iteration: 2/20, moves: 379, ncost: 794087061873.0835
# Run: 9, iteration: 3/20, moves: 200, ncost: 788820337682.353
# Run: 9, iteration: 4/20, moves: 121, ncost: 786870228602.3744
# Run: 9, iteration: 5/20, moves: 87, ncost: 785903097925.9775
# Run: 9, iteration: 6/20, moves: 51, ncost: 785606912443.4146
# Run: 9, iteration: 7/20, moves: 18, ncost: 785557453367.9032
# Run: 9, iteration: 8/20, moves: 7, ncost: 785550664653.3425
# Run: 9, iteration: 9/20, moves: 7, ncost: 785545634415.155
# Run: 9, iteration: 10/20, moves: 0, ncost: 785545634415.155
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run: 10, iteration: 1/20, moves: 1516, ncost: 906273111643.5165
# Run: 10, iteration: 2/20, moves: 753, ncost: 829205236225.1034
# Run: 10, iteration: 3/20, moves: 481, ncost: 800055367361.402
# Run: 10, iteration: 4/20, moves: 284, ncost: 790422525351.0522
# Run: 10, iteration: 5/20, moves: 155, ncost: 787331663278.2163
# Run: 10, iteration: 6/20, moves: 93, ncost: 786183724462.9105
# Run: 10, iteration: 7/20, moves: 67, ncost: 785655956320.5769
# Run: 10, iteration: 8/20, moves: 26, ncost: 785566620155.1418
# Run: 10, iteration: 9/20, moves: 10, ncost: 785551468522.3025
# Run: 10, iteration: 10/20, moves: 6, ncost: 785546422486.777
# Run: 10, iteration: 11/20, moves: 2, ncost: 785545634415.1553
# Run: 10, iteration: 12/20, moves: 0, ncost: 785545634415.1553
# Best run was number 9

# %%
print(kproto.cluster_centroids_)
# Out:
# [array([[8.04338174e+03, 8.29341174e+04, 9.09228225e+01, 4.76527012e+01],
#        [8.33216831e+03, 5.46449257e+04, 9.51337668e+01, 4.91597771e+01],
#        [8.03295458e+03, 2.66208754e+04, 9.26217544e+01, 4.69445614e+01]]), array([['California', 'Basic', 'Rural'],
#        ['California', 'Basic', 'Suburban'],
#        ['California', 'Basic', 'Suburban']], dtype='<U10')]

# %%
len(clusters)
# Out:
# 6817

# %%
len(marketing_df)
# Out:
# 6817

# %%
clusters_list = list(clusters)

# %%
marketing_df['cluster'] = clusters_list

# %%
marketing_df[marketing_df['cluster']==0]
# Out:
#            State           CLV Coverage  Income  loc_type  monthly_premium  \
# 7     California   8798.797003  Premium   77026     Urban              110
# 8        Arizona   8819.018934    Basic   99845  Suburban              110
# 9     California   5384.431665    Basic   83689     Urban               70
# 19        Oregon   5802.065978    Basic   97541  Suburban               72
# 21       Arizona  12902.560140  Premium   86584  Suburban              111
# ...          ...           ...      ...     ...       ...              ...
# 6790  California   5926.385440    Basic   92949     Urban               74
# 6792  California   7083.642205  Premium   97024     Urban              177
# 6797  California   2619.337376    Basic   78618     Urban               66
# 6802  California   2845.520933    Basic   86631  Suburban               73
# 6814  California  23405.987980    Basic   71941     Urban               73
#
#       Months_Since_Policy_Inception  cluster
# 7                                82        0
# 8                                25        0
# 9                                10        0
# 19                                1        0
# 21                               54        0
# ...                             ...      ...
# 6790                             84        0
# 6792                             68        0
# 6797                             56        0
# 6802                             44        0
# 6814                             89        0
#
# [1814 rows x 8 columns]

# %%
marketing_df[marketing_df['cluster']==1]
# Out:
#            State           CLV  Coverage  Income  loc_type  monthly_premium  \
# 0     Washington   2763.519279     Basic   56274  Suburban               69
# 1         Nevada  12887.431650   Premium   48767  Suburban              108
# 2     Washington   2813.692575     Basic   43836     Rural               73
# 3         Oregon   8256.297800     Basic   62902     Rural               69
# 4         Oregon   5380.898636     Basic   55350  Suburban               67
# ...          ...           ...       ...     ...       ...              ...
# 6808  California   9424.256842     Basic   46897     Urban              118
# 6809  California   5479.555081     Basic   56005  Suburban               68
# 6811  California  16261.585500  Extended   60646  Suburban              134
# 6812  California   5032.165498     Basic   66367  Suburban               64
# 6813  California   4100.398533   Premium   47761  Suburban              104
#
#       Months_Since_Policy_Inception  cluster
# 0                                 5        1
# 1                                38        1
# 2                                44        1
# 3                                94        1
# 4                                13        1
# ...                             ...      ...
# 6808                             11        1
# 6809                             30        1
# 6811                             42        1
# 6812                             48        1
# 6813                             58        1
#
# [2153 rows x 8 columns]

# %%
marketing_df[marketing_df['cluster']==2]
# Out:
#            State           CLV  Coverage  Income  loc_type  monthly_premium  \
# 5         Oregon  24127.504020     Basic   14072  Suburban               71
# 6         Oregon   7388.178085  Extended   28812     Urban               93
# 10        Oregon   7463.139377     Basic   24599     Rural               64
# 11        Nevada   2566.867823     Basic   25049  Suburban               67
# 12    California   3945.241604     Basic   28855  Suburban              101
# ...          ...           ...       ...     ...       ...              ...
# 6805  California   7501.661322  Extended   38874     Urban               94
# 6806  California   5133.397765     Basic   28647  Suburban               69
# 6810  California  25464.820590  Extended   13663  Suburban               97
# 6815  California   3096.511217  Extended   21604  Suburban               79
# 6816  California   7524.442436  Extended   21941  Suburban               96
#
#       Months_Since_Policy_Inception  cluster
# 5                                 3        2
# 6                                 7        2
# 10                               50        2
# 11                                7        2
# 12                               59        2
# ...                             ...      ...
# 6805                             86        2
# 6806                             59        2
# 6810                             66        2
# 6815                             28        2
# 6816                              3        2
#
# [2850 rows x 8 columns]
