# %%
import pandas as pd
import numpy as np
import time
import os

import spacy

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv1D, MaxPool1D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
df = pd.read_csv('vehicle_df.csv', index_col = 0).reset_index(drop = True)

# %%
df.head()
# Out:
#         Order                               Description Total planned costs  \
# 0  1102603947        21293-TRUCK CARRYALL INSP-12 MONTH              448.48
# 1  1102603946  20031-TRK CARGO TO 3 1/2 PERIODIC INSPEC              448.48
# 2  1102603468  16650-TRK CARGO TO 3 1/2 T INSP-12 MONTH              448.48
# 3  1102602653     22711-FORKLIFT ICED RT  INSP-12 MONTH              448.48
# 4  1102602646  18070-TRK CARGO TO 3 1/2 T INSP-12 MONTH              448.48
#
#    PM Orders planned hours Technical Status  PM Orders actual hours  \
# 0                      4.0              nil                     0.0
# 1                      4.0              nil                     0.0
# 2                      4.0              nil                     0.0
# 3                      4.0              nil                     0.0
# 4                      4.0              nil                     0.0
#
#   Tail Number / Identifier User Status   Equipment MaintActivityType  \
# 0               2017-21293        CRTD  20959842.0               L27
# 1               2017-20031        CRTD  20938634.0               L27
# 2               2015-16650        CRTD  20895249.0               L27
# 3               2017-22711        CRTD  21019809.0               L27
# 4               2016-18070        CRTD  20916080.0               L27
#
#   Main work center Vehicle Type  Utilizer Actual release date  \
# 0         AG-I---2       EV0A80       102                 nil
# 1         AG-I---2       EV0B16       102                 nil
# 2         AG-I---2       EV0B16       102                 nil
# 3         AG-S--V2       EV0F81       102                 nil
# 4         AG-I---2       EV0B16       102                 nil
#
#   Basic finish date  days WIP
# 0        27/07/2020         0
# 1        27/07/2020         0
# 2        25/07/2020         0
# 3        23/07/2020         0
# 4        23/07/2020         0

# %%
text = df['Description'].tolist()
token = Tokenizer()
token.fit_on_texts(text)
vocab = token.index_word + 1
encoded_text = token.txt_to_sequences(text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-6957fff0e2dd> in <module>
#       2 token = Tokenizer()
#       3 token.fit_on_texts(text)
# ----> 4 vocab = token.index_word + 1
#       5 encoded_text = token.txt_to_sequences(text)
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'int'

# %%
# Out:
# ['21293-TRUCK CARRYALL INSP-12 MONTH',
#  '20031-TRK CARGO TO 3 1/2 PERIODIC INSPEC',
#  '16650-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '22711-FORKLIFT ICED RT  INSP-12 MONTH',
#  '18070-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '12644-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '11887-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '11720-TRUCK CARRYALL INSP-12 MONTH',
#  'inspection complete, repairs WO opened',
#  '14496-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '16644-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '21154-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '20034-TRK CARGO TO 3 1/2 PERIODIC INSPEC',
#  '17567-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  '17203-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  'Mobile Crane Certification [24268]',
#  '11600-TRK TPT/UTIL TO 7T INSP-12 MONTH',
#  '68389 VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '65342- 12 MONTH VEH INSP',
#  '21299-TRUCK CARRYALL INSP-12 MONTH',
#  '17947-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  'AUTO SEDAN INSP-12 MONTH',
#  '23280-TRUCK PANEL OVER 1T  INSP-12 MONTH',
#  '13706-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '19906-VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '73096 - TRAILER MISC INSP-12 MONTH',
#  '17946-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  '14547-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '24772- Replace windshield',
#  '24297-AUTO SEDAN INSP-12 MONTH',
#  '20233-Repairs after',
#  '*19995 SAFETY RECALL N182165790',
#  '*16767 HYDRAULIC LEAK',
#  '*13749 HOLE IN HOSE',
#  '*13749 ESTIMATE FOR DAMAGE AND REPAIR',
#  "*13749 DENT ON DRIVER'S SIDE DOOR",
#  '*13748 DAMAGE ESTIMATE FOR WIND DAMAGE',
#  '*11917 Rebluild sifter screen',
#  '06278-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '94424-FORKLIFT EMD INSP-12 MONTH',
#  '96613- TRACTOR WH AGRIC INSP-12 MONTH',
#  'VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '*93688 DESICCANT FILTER IS ALMOST EXPIRE',
#  '82921 - Brakes N/S',
#  'Repairs after inspection',
#  '*21630 COOLANT TOP UP/ HYDRAULIC FLUID T',
#  '21301-TRUCK CARRYALL INSP-12 MONTH',
#  '*04145  GASKET NEEDS REPLACING',
#  '*12633 MULTIPLE DEFECTS',
#  '96680 Inspection repairs',
#  '24619-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*23281 OIL CHANGE REQUIRED',
#  '*22236 TIRE PRESSURE LIGHT ON',
#  '20234-Repairs after',
#  '19982-repairs after',
#  '17946-Repairs after',
#  '*16638 TAIL GATE CAP FALLLING OFF',
#  'Install +100 shut off & drain valve',
#  '*13747 HP HOSE SENSOR DISINTEGRATED, VOR',
#  '11917 Replace connector',
#  '*11600 A/C NOT WORKING',
#  '*00878 TWO NEW FRONT TIRES NEEDED',
#  '*54315 EMO IN INSP',
#  '*53850 EMO IN INSPECTION REQUIRED',
#  '*68504 HYDRAULIC ISSUES',
#  '93685 - Repairs After Inspection',
#  '93685 - Close Proximity Inspection',
#  '*16286 EIS REQUIRED TO BE ORDERED',
#  "*21299 X 4 SUMMER TIRES REQ'D",
#  "*20233 RRR VEHICLE WON'T START",
#  '*13749 Truck will not pump',
#  '42811 repairs',
#  'Repairs after inspection',
#  '22963-TRUCK DUMP S/C INSP-12 MONTH',
#  '3422-2 Hyd leak rr inner hub',
#  '*04143 STICKS IN 2ND GEAR, RPM WILL INCR',
#  '*96613 REQUIRES REPLACEMENT BATTERY',
#  'TLR MILITARISED INSP-12 MONTH',
#  '*24763 OIL LEAK UNDERNEATH VEHICLE',
#  '24587-TLR COMMERCIAL INSP-12 MONTH',
#  '24586-TLR COMMERCIAL INSP-12 MONTH',
#  '24585-TLR COMMERCIAL INSP-12 MONTH',
#  "*22267 4 X SUMMER TIRES REQ'D",
#  '*21299 OIL CHANGE REQUIRED',
#  '21305-TRUCK CARRYALL INSP-12 MONTH',
#  '20234-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '19982-TRUCK CARRYALL INSP-12 MONTH',
#  '11881- Repairs after',
#  '11881-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '05199 - Reapirs after',
#  '00878 - TRACTOR WH AGRIC PERIODIC INSPEC',
#  '*53905 FUEL LINE/PUMP ISSUE',
#  '69377 - FORKLIFT ICED INSP-12 MONTH',
#  '*13531 EMO IN INSPECTION  REQUIRED',
#  'Repairs after inspection',
#  '*16547 OIL CHANGE REQUIRED',
#  'Repairs after inspection',
#  '*12633 CAB HEATER LEAKING OIL, AIR LEAK',
#  '24611-AUTO SEDAN INSP-12 MONTH',
#  '*23765 ENGINE LIGHT ON ( YELLOW )',
#  '23765 - AMBULANCE MAJOR INSPECTION',
#  '22525-REPAIRS AFTER',
#  '*22236 LOOSE HEAT SHIELD REAR RIGHT',
#  '*22232 License plate light N/S',
#  '17360-repairs after',
#  '3422-2 Quarterly Inspection',
#  '*12993 SAFETY RECALLS 19E02 & 19S17',
#  'TRK TPT/UTIL TO 7T INSP-12 MONTH',
#  '01241- 2 year coalescor filter change',
#  'EXCAVATOR SELFPROP INSP-12 MONTH',
#  '12633 Repairs after inspectuion',
#  '65168 - TRAILER MISC INSP-12 MONTH',
#  '*75919 MULTIPLE DEFECTS',
#  'TRK TANK EXCEPT A/S INSP-12 MONTH',
#  'TRK TANK EXCEPT A/S INSP-12 MONTH',
#  'TRK TANK EXCEPT A/C INSP-12 MONTH',
#  '70298-TRK TANK EXCEPT A/C INSP-12 MONTH',
#  '17360-TRUCK PANEL OVER 1T INSP-12 MONTH',
#  '*14541 HOSE IS HISSING PROPANE, RRR',
#  '81323 - repairs after inspection',
#  'Repairs after inspection',
#  'Repairs after inspection',
#  '*16767 CHARGING CABLE CUT RRR',
#  '96768 Major inspection Repairs',
#  'Repairs after inspection',
#  '*20032 DAMAGE REPAIR ESTIMATE DUE TO ACC',
#  '20032-TRK CARGO TO 3 1/2 PERIODIC INSPEC',
#  '*14260 SAFETY RECALL',
#  '*12601 BATTERY ISSUES RRR',
#  '*94424 BATTERY DEAD, NEEDS REPLACING',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  '[93688]-REFUELLER VEHICLE INSPECTION',
#  '*64558 PTO NOT ENGAGING/ BARCKET BROKE',
#  '*22574 GRADER NEEDS CUTTING EDGE',
#  '19765-REPAIRS AFTER',
#  '05882-DFFU ANNUAL INSP-12 MONTH',
#  '*00969 REQUIRES NEW SUMMER TIRES',
#  '*24611 RRR VEHICLE QUIRES TO BE BOOSTED',
#  '22525-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '21295-TRUCK CARRYALL INSP-12 MONTH',
#  '20198-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '19765-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '19688-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*18084 LFT REAR SHOCK N/S, SUMMER TIRES',
#  '*16550 NEW TIRES NEEDED',
#  '11785-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*01241  HOLDER BROKEN/OFF THE TRACK',
#  '96768 Major inspection',
#  '17997-TRK TPT/UTIL TO 7T INSP-12 MONTH',
#  '*68505 REPAIR /REPLACE LEFT SIDE DOOR WI',
#  '[65298]-REFUELLER VEHICLE INSPECTION',
#  '*25333 LOWER AND CUT EXHUAST STACK',
#  '*17569 SUMMER TIRES TO BE SWAPPED OUT',
#  '17569-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  '03346 - repairs after',
#  '20212-REPAIRS AFTER',
#  '20106-Repairs',
#  '*13747 VIPER CALIBRATION',
#  '11591 -  INSPECTION Repairs',
#  '82914-Diagnose no Start',
#  '82923-Diagnose No Start',
#  '*21304 SWAP OUT WINTER TIRES',
#  '20198-REPAIRS AFTER',
#  '*17204 CHANGE OIL LIGHT CAME ON',
#  '*17204 NEW BATTERY REQUIRED',
#  '*13748 TRUCK DESICCANT FILTER/ GRD CABLE',
#  'SWEEPER ROT SELFPROP INSP-12 MONTH',
#  '42811 repairs',
#  'TRACTOR FULL TRACKED INSP-12 MONTH',
#  'DVSPM NFPA1911 AERIAL Greenwood UIC 0102',
#  '20106-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '14469 - repairs after',
#  'coolant leak, replace radiator',
#  '*11591 REAR BRAKES LOCKING/SEIZING',
#  '*03346 CUT AND LOWER EXHUAST STACK',
#  '*12633 MULTIPLE DEFECTS',
#  'Repair after inspection',
#  'BUS OVER 28 PAX INSP-6 MONTH',
#  '69049-Inspection repairs',
#  '18779- Repair Rear Wiper/Window Seal',
#  '*13751 CHECK ENGINE LIGHT/ INLET AUX HEA',
#  'TRACTOR WH A/C TOW M INSP-12 MONTH',
#  '*24763 SAFETY RECALL N192264501',
#  '24393-VEHICLE ALL TERRAIN INSP-12 MONTH',
#  'After market request',
#  '24392-VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '*24144 SAFETY RECALL N192261050',
#  '*23765 CHECK ENGINE LIGHT ON',
#  '*23733 SAFETY RECALL N192264501',
#  '*22232 REAR WHITE LICENSE PLATE LIGHT',
#  '*21410 SAFETY RECALL N182165790',
#  '20212-AUTO SEDAN INSP-12 MONTH',
#  '*14495 SAFETY RECALL VB1',
#  '*14260 SAFETY RECALL N182176760 EXHUAST',
#  '*13718 SAFETY RECALL N172086770',
#  '11917-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*05851 CHECK ENGINE LIGHT ON',
#  '82979 - TRAILER MISC INSP-12 MONTH',
#  '69288-VEHICLE MOUNTED AERIAL DEVICE',
#  '12600-AUTO SEDAN INSP-06 MONTH',
#  "*24264 PROPANE F/L WON'T START",
#  '*23796 SWAP OUT WINTER TIRES',
#  '*22527 OIL CHANGE REQ/ WINTER TIRES CHAN',
#  '*05199 SWAP OUT WINTER TIRES',
#  '23323-TRUCK DUMP S/C INSP-12 MONTH',
#  '66195 - TRAILER MISC INSP-12 MONTH',
#  '66197 - TRAILER MISC INSP-12 MONTH',
#  '66193 - TRAILER MISC INSP-12 MONTH',
#  '[13748]-REFUELLER VEHICLE INSPECTION',
#  '*11591 BOTTOM HALF OF LIGHT NOT WORKING',
#  '*04143 WATER LEAK IVO PUMP',
#  '*93685 DIFF PRESSURE .5/ GROUNDING CABLE',
#  '*65253 COLLISION DAMAGE ESTIMATE',
#  '*24144 SWAP OUT WINTER TIRES',
#  '*22231 VEHICLE REQUIRES OIL CHANGE',
#  '*21293 OIL CHANGE REQUIRED',
#  '*12601 SAFETY RECALL 20S04',
#  '*12600 SAFETY RECALL 20S04',
#  '[13752]-REFUELLER B620 CERTIFICATION',
#  '93688 Repairs After Inspection',
#  '93688 Annual Inspection',
#  'Repairs after',
#  '23018-LOADER SCOOP INSP-12 MONTH',
#  '22964-TRUCK DUMP S/C INSP-12 MONTH',
#  '17716-LOADER SCOOP INSP-12 MONTH',
#  '12601-AUTO SEDAN INSP-06 MONTH',
#  '29727 Repair after inspection',
#  '8TRACTOR WH A/C TOW M INSP-12 MONTH',
#  '14353-CARRIER O/SNOW SM/LD INSP-12 MONTH',
#  '82998-TRAILER MISC INSP-12 MONTH',
#  '82981- TRAILER MISC INSP-12 MONTH',
#  '82943- TRAILER MISC INSP-12 MONTH',
#  '22973-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  'TRUCK DUMP S/C INSP-12 MONTH',
#  '*12601 BATTERY ISSUE',
#  '*12601 CHECK ENGINE LIGHT ON, SWAP OUT T',
#  '*93276 FLAT TIRE NEEDS CONTRACT RAISED',
#  '01606 Replace seal',
#  '*68505 Oil leak',
#  '*75919 MULTIPLE DEFECTS',
#  '[13749] Repairs after inspection',
#  '[13749] REFUELLER VEHICLE INSPECTION',
#  '*21295 SWAP OUT WINTER TIRES',
#  '90943 Blower motor stuck on high speed',
#  '90352 Repair after inspection',
#  '29727 Inspection',
#  '13751 Replace underwing refueling hose',
#  '24397-VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '24396-VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '24395-VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '24394-VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '02418- LOADER SKID STEER INSP-12 MONTH',
#  '*13748 LOW PRESSURE NOZZLE LEAKING',
#  '*01241 LOW PRESSURE NOZZLE LEAKING',
#  '12909- TLR AAGSE INSP-12 MONTH',
#  '82914-Repairs After',
#  '25045 Switch equipment',
#  '25044 Switch equipment',
#  '25043 switch equipment',
#  '23370-TLR COMMERCIAL INSP-12 MONTH',
#  '23369-TLR COMMERCIAL INSP-12 MONTH',
#  '23366-TLR COMMERCIAL INSP-12 MONTH',
#  '22524-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '18779 - TLD Service Bulletin',
#  '19689-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*13677 LIGHT CORD CUT OFF',
#  '*13060 MULTIPLE DEFECTS',
#  '*12993 MVRS DISPLAYS/SWAP OUT TIRES',
#  '*11708 HUB ODOMETER N/S',
#  '*11591 RIGHT REAR DISCHARGE HANDLE STUCK',
#  '04145 - F/F MAJOR INSPECTION',
#  '*64558 PTO WILL NOT ENGAGE',
#  '64556 Remove equipment',
#  '64559 Remove equipment',
#  '[13752] Repairs after inspection',
#  '[13752] REFUELLER VEHICLE INSPECTION',
#  '[13750] Repairs after inspection',
#  '[13750] REFUELLER VEHICLE INSPECTION',
#  '12993-MISC S/P & CARGO VEH INSP-6 MONTH',
#  '[14214]-REFUELLER VEHICLE INSPECTION',
#  '[14214]-REFUELLER B620 CERTIFICATION',
#  '14468-AUTO SEDAN INSP-12 MONTH',
#  '[13751] REFUELLER VEHICLE INSPECTION',
#  '82934-Diagnose Start Issue',
#  '72980- TRACTOR WH AGRIC INSP-12 MONTH',
#  '72978- TRACTOR WH AGRIC INSP-12 MONTH',
#  '72977- TRACTOR WH AGRIC INSP-12 MONTH',
#  '12928- TLR AAGSE INSP-12 MONTH',
#  '12927- TLR AAGSE INSP-12 MONTH',
#  '12926- TLR AAGSE INSP-12 MONTH',
#  '12908- TLR AAGSE INSP-12 MONTH',
#  '12907- TLR AAGSE INSP-12 MONTH',
#  '[14214]-repairs after inspection',
#  '18778 - TLD Service bullentin repair',
#  '18777 - TLD Service bullentin repair',
#  '18776 - TLD Service bullentin repair',
#  '18775 - TLD Service bullentin repair',
#  '19988-TRUCK CARRYALL INSP-12 MONTH',
#  '54032 Repair after inspection',
#  '12906- TLR AAGSE INSP-12 MONTH',
#  '[13751repairs after inspection',
#  '*93685 CHECK ENGINE LIGHT ON/ DIFF PRESS',
#  '[13747] REFUELLER VEHICLE INSPECTION',
#  '*11600 Check engine light on',
#  'Repairs after inspection',
#  '*75920 REQUIRES A LATCH TO BE INSTALLED',
#  '64558 Remove Equipment',
#  '21560-TRAILER MISC INSP-12 MONTH',
#  '13751 Close Proximity Inspection',
#  '11603-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '11602-TRUCK PANEL OVER 1T  INSP-12 MONTH',
#  '[13747] Repairs afer inspection',
#  '82934-Diagnose Intermitant No Start',
#  'Warranty repairs after EMO',
#  '*22527 SWAP OUT WINTER TIRES',
#  '*22238 SWAP OUT WINTER TIRES',
#  '*22237 SWAP OUT WINTER TIRES',
#  '*22236 SWAP OUT WINTER TIRES',
#  '22231-TRUCK CARRYALL INSP-12 MONTH',
#  '*22103 SWAP OUT WINTER TIRES',
#  '*21293 SWAP OUT WINTER TIRES',
#  '18773 - TLD Service bullentin repair',
#  '*14496 SWAP OUT WINTER TIRES',
#  '*14468 SWAP OUT WINTER TIRES',
#  '*11591 Rear compartment lights N/S',
#  '05504- TRACTOR WH AGRIC INSP-12 MONTH',
#  '[01241]-REFUELLER VEHICLE INSPECTION',
#  'MSVS INSP-12 MONTH',
#  '93685 - Meter Repair',
#  '93686 R-11 WAIVER Damage Citerne',
#  '23766 - AMBULANCE MAJOR INSPECTION',
#  '18778-Repairs After',
#  '*22233 SWAP OUT WINTER TIRES',
#  '*21299 TIRE REPAIR REQUIRED',
#  '*04143 TRUCK GETS STUCK IN 2ND GEAR/TRUC',
#  '*93273 SLOW LEAK IN TIRE, ALSO NEEDS SLA',
#  '*02469 HYDRAULIC LEAK BETWEEN FRONT AXEL',
#  '*18461 NUMEROUS ISSUES',
#  '[01241]-REPAIRS AFTER INSPECTION',
#  '23246-MISC CONST EQPT INSP-12 MONTH',
#  '17289-TRUCK PANEL OVER 1T INSP-12 MONTH',
#  '*04143 EXHUAST PIPE FLANGE BENT',
#  '[93686]-Repairs after inspection',
#  '[93686]-REFUELLER VEHICLE INSPECTION',
#  '05880-DFFU ANNUAL INSP-12 MONTH',
#  '*25045 EMO IN INSPECTION REQUIRED',
#  '*25044 EMO IN INSPECTION REQUIRED',
#  '*25043 EMO IN INSPECTION REQUIRED',
#  'Mobile Crane Certification [24268]',
#  '18778-TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '13750 repairs after Inspection',
#  '13750 Close Proximity Inspection',
#  '*13747 FRONT DVR SIDE HEADLIGHT BURNT OU',
#  '*11591 Oil Change needed.',
#  '*93685  Filter problems',
#  '61286 - F/F MAJOR INSPECTION',
#  '16646 replace batteries',
#  '16646 replace batteries',
#  '93688 Replace coalescor filters',
#  '24564-FORK LIFT BED/LPG INSP-12 MONTH',
#  '22527-AUTO SEDAN INSP-12 MONTH',
#  '21304-TRUCK CARRYALL INSP-12 MONTH',
#  '17921-SNOWBLOWER HEAD INSP-12 MONTH',
#  '17565-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  '14469-AUTO SEDAN INSP-12 MONTH',
#  '30515- TRAILER MISC INSP-12 MONTH',
#  '30513- TRAILER MISC INSP-12 MONTH',
#  '24256-VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '30521- TRAILER MISC INSP-12 MONTH',
#  '30519- TRAILER MISC INSP-12 MONTH',
#  '*22267 LARGE CRACK ACROSS WINDSHIELD',
#  '22233-TRUCK CARRYALL INSP-12 MONTH',
#  '21296-TRUCK CARRYALL INSP-12 MONTH',
#  '21294-TRUCK CARRYALL INSP-12 MONTH',
#  '19839-VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '17699-TLR COMMERCIAL INSP-12 MONTH',
#  '17564-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  '*14495 CHECK ENGINE LIGHT IS ON',
#  'MSVS INSP-12 MONTH',
#  '*54208 LEAK IN FRONT PAX TIRE',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  '*93276 LEAK FRONT PAX TIRE VALVE STEM',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'CORROSION CONTROL PROGRAM FY 20-21',
#  'replace radiator',
#  '21290-TRUCK CARRYALL INSP-12 MONTH',
#  '*16545 DAMAGE/REPAIR ESTIMATE',
#  '04201-FORKLIFT EMD INSP-12 MONTH',
#  'LUVW MIL COTS INSP-12 MONTH',
#  '18772-TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '18102-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '14196-TRUCK CARRYALL INSP-12 MONTH',
#  'TRACTOR WH AGRIC INSP-12 MONTH',
#  'TRUCK TRACTOR S/C INSP-12 MONTH',
#  '24144-TRUCK CARRYALL INSP-12 MONTH',
#  '02786-FORKLIFT ICED INSP-12 MONTH',
#  '81229- FORKLIFT ICED INSP-12 MONTH',
#  '16740-SELF-PROPELLED AERIAL DEVICE',
#  '24111-FORK LIFT BED/LPG INSP-12 MONTH',
#  '19983-TRUCK CARRYALL INSP-12 MONTH',
#  '17570-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  'TRAILER MISC INSP-12 MONTH]',
#  'BUS OVER 28 PAX INSP-6 MONTH',
#  '17989-TRUCK DUMP S/C INSP-12 MONTH',
#  '17568-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  'Repairs After Inspection',
#  'Close Proximity Inspection',
#  '18773 - Repairs After',
#  '18773-TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '*05850 CHECK ENGINE LIGHT STAYING ON',
#  '57625 - Boost/Recover',
#  '21847-TLR COMMERCIAL INSP-12 MONTH',
#  '82914-Recover From 7 Hgr',
#  '82924-Recover From ARO (10 Hgr)',
#  '*20034 SAFETY RECALL BLOCK HEATER WIRE',
#  '*13750 NO TENSION ON HOSE',
#  '*00969 COOLANT LEAK',
#  '90352 EMO OUT',
#  '*96768 MULTIPLE DEFECTS',
#  'Blade shappening',
#  '69049-TLR COMMERCIAL INSP-12 MONTH',
#  '18779- Check For Signs Of Wet Stacking',
#  '19042-Repair after inspection',
#  "*12600 OIL CHANGE REQ'D",
#  '*12750 A/C HANDLING EQUIP FRT TIRES',
#  'TRAILER MISC INSP-12 MONTH',
#  '57624-Recover From 11 Hgr',
#  '*19906 INSPECTION DUE',
#  '*19906 Repairs after',
#  '*16635 SAFETY RECALL',
#  '14399-SWEEPER ROT SELFPROP Repairs',
#  '*75919 STEERING LINKAGE VERY LOOSE',
#  '*72925 Zamboni needs blades sharpened.',
#  'EIS after market request',
#  '*23568 SAFETY RECALL U94',
#  '21852-TLR COMMERCIAL INSP-12 MONTH',
#  '18777-TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '19839-Repairs after inspection',
#  '19467-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  'Boom hydraulic control coils N/S',
#  '17210-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*14546 OIL CHANGE REQUIRED',
#  '13677-TRAILER MISC INSP-12 MONTH',
#  '*11602 REPAIR FLAT TIRE ON PAX REAR SIDE',
#  "*01964 EMO OUT INSPECTION REQ'D",
#  'Repairs after inspection',
#  '*12633 MULTIPLE DEFECTS',
#  '*83714 FUEL LEAK FROM FUEL TANK',
#  '93685 Repairs after inspection',
#  '93685 Annual Inspection',
#  'Castors',
#  'Castors',
#  '22574-GRADER MOTORIZED INSP-12 MONTH',
#  '17568 Repairs after inspection',
#  '*17566 OIL CHANGE REQUIRED',
#  '*14481 SAFETY RECALL N182202780',
#  '*12601 NO EMERGENCY EQUIPMENT WORKING',
#  '*01241 BATTERIES ARE DEAD',
#  'After market request',
#  '19912-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*13749 +100 LEAKING BY VIPER SYSTEM',
#  '57625 - Repairs after insp',
#  'TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '*22524 OIL CHANGE REQUIRED',
#  '*22267 OIL CHANGE REQUIRED',
#  'Repair After inspection',
#  '*20233 RRR FOR DEAD BATTERY',
#  '17080 - Epoke Trng',
#  '16715 Repairs after inspection',
#  "*13751 WON'T CONTINUE TO PUMP",
#  '*11917 MISSING RETURN SPRING ON PLOW',
#  'Repair blade holder',
#  '*05850 MULTIPLE DEFECTS',
#  '*02787 RRR',
#  'TRK CARGO TO 3 1/2 T INSP Repairs',
#  '*53905 BLACK OUT DRIVE LIGHT OUT',
#  '*75920 FRONT SHOCKS, FRONT WHEEL ALIGNME',
#  '78613-reaplace lift cylinders',
#  '*65253 LEFT CYLINDER BROKE OFF ( WELDING',
#  '*46110 RT SIDE PLOW CYLINDER BOLT SHEARE',
#  '19984- repairs after inspection',
#  '*11917 WARNING LIGHT TLR PLUG WIRING SCR',
#  '93686 Repairs After Inspection',
#  '93686 Close Proximity Inspection',
#  '46110- Replace plow blade RHS cylinder',
#  '*23567 REPROGRAM POWER CONTROL MODULE',
#  '21213-BUS UP TO 28 PAX 6 MON INSPECTION',
#  '*20233 VECHILE NEEDS WINTER TIRES PUT ON',
#  '19984-REPAIRS AFTER INSPECTION',
#  '*17209 WIRING LOOSE ON TOWER RADIO',
#  '*16640 SAFETY RECALL V06 DRAG LINK',
#  '14399-SWEEPER ROT SELFPROP INSP-12 MONTH',
#  '*12601 CHECK ENGINE LIGHT ON/ EGG SMELL',
#  '11790 Replace Battery',
#  '*11600 REQUIRES STATIC STRAP INSTALLED',
#  '06469-BUS UP TO 28 PAX 6 MON INSPECTION',
#  'TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*00880 1 X FRONT TIRE BLOWN, 1 BULGING F',
#  '*12633 DVR SIDE LOW BEAM N/S AIR HORN RI',
#  'TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '*65254 ENGINE KEEPS SHUTTING DOWN',
#  '*13751 ENGINE LIGHT ( INTEL AIR HEATER )',
#  '*13751 ENGINE LIGHT ON (INTEL AIR HEATER',
#  '*23544 SAFETY RECALL U94',
#  '*18102 SAFETY RECALL V06 DRAG LINK',
#  '*16644 SAFETY RECALL V06 DRAG LINK',
#  '13752 repairs After Inspection',
#  '*04143 PARKING BRAKE BUTTON PARTIALLY BR',
#  '13752 Close proximity Inspection',
#  '*18102 REAR DVR SIDE TURN SIGNAL N/S',
#  "*18084 DRIVER'S SIDE SUN VISOR BROKE",
#  '13749 Repairs after inspection',
#  '13749 Close proximity inspection',
#  '*12993 POWER STEERING, CHARGING ISSUES',
#  '*65250 DRIVESHAFT BROKE',
#  '22964-No start',
#  '22963- No start',
#  '22526-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '22265-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '23630 - F/F MINOR INSPECTION',
#  '17209-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  "*17203 EMO OUT INSPECTION REQ'D",
#  '14436-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*13748 HP HOSE REEL TOO TIGHT',
#  "*11720 EMO OUT INSPECTION REQ'D",
#  '*02470 CRADLE WILL NOT LIFT OPEN',
#  "*13531 EMO OUT INSPECTION REQ'D",
#  '*46110 CUTTING EDGES REQUIRED',
#  '*48659 DASH & REVERSE LIGHTS N/S',
#  '*13750 TRUCK IS RELUCTANT TO START BATT',
#  '*13748 HI PRESSURE HOSE IS TOO RIGID',
#  '11715-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*00555 CHAIN GUARD ON NOZZLE BROKEN OFF',
#  '00511- Replace tires',
#  '*25333 REQUIRES EMO IN INSPECTION',
#  '*21213 DEAD BATTERIES, ONE BATTERY HAS A',
#  '*20236 SAFETY RECALL N192217410',
#  '*19933 OIL CHANGE REQUIRED',
#  '*13061 BRAKES NOT WORKING',
#  '*13061 Park brake N/S',
#  '*13061 CHAIN FOR SPREADER VERY LOOSE',
#  '*06003 RIGHT REAR BRUSH ON SWEEPER N/S',
#  'Repair after inspection',
#  '*04143 POWER CABLE AUTO-EJECT COVER OFF',
#  '02787-FORKLIFT ICED INSP-6 MONTH',
#  '95707-Replace tire',
#  '[93688]-REFUELLER VEHICLE INSPECTION',
#  '*65249 BROOM IS CONED, BOLTS RUBBING FRA',
#  '*17945 SAFETY RECALL N192217410',
#  '*17568 SAFETY RECALL N192217410',
#  "*90291 EMO IN INSPECTION REQ'D",
#  '69636-Diagnose Hydraulic Leak',
#  '*65254 TEE PLACE SNAPPED OFF',
#  '*65702 STOP ENGINE LIGHT ON',
#  '*65702 RAD LEAK/ CRACK ON PLATE',
#  '*46110 SWEEPER NOT WORKING WHEN ATTACHED',
#  '*24256 EMO IN INSPECTION',
#  '22224-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '18776-TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '17569 AFTERMARKET REQUEST',
#  '17208-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*24586 VALVE STEMS BOTH TIRES NEED REPLA',
#  "*22527 FOG LIGHT ON DVR'S SIDE OUT",
#  '19984-TRUCK CARRYALL INSP-12 MONTH',
#  '*13752 ESTIMATE FOR DAMAGE & REPAIR',
#  'TRACTOR WH AGRIC PERIODIC INSPECTION',
#  '*13531 VALVE LEAKING CONSTANTLY',
#  '*13060 Park brake N/S',
#  'No start',
#  '*02419 STARTER LOCKED UP',
#  'ANTI-CORROSION PROGRAM FY 19-20',
#  'Carc paint',
#  '41056- VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '78594- LHS lift cylinder seeping',
#  '*65251 (Drive Shaft)',
#  'Castors',
#  '18773 - TLD Service bullentin repair',
#  '*13750 SUMP HANDLE LOOSE DVR REAR SIDE M',
#  '*02185 SAFETY RECALL AIRBAG RECALL',
#  'CFR: 96768 TRACKTOR- ELECTRICAL ISSUES',
#  'Hydraulic leak',
#  '*20235 REQUIRES OIL CHANGE',
#  '*13747 WINDSHIELD WASHER PIPE DVR SIDE',
#  '[93688]-Repairs after inspection',
#  '22232-TRUCK CARRYALL INSP-12 MONTH',
#  '*18001 COST/ESTIMATE FOR DAMAGE/REPAIR',
#  '17211-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  '*14580 CUTTING EDGES REQUIRED',
#  '*13061 SPRING BRAKES NOT HOLDING TRUCK',
#  'TRACTOR WH AGRIC INSP-12 MONTH',
#  "*05504 HARD TO START, SOMETIMES WON'T ST",
#  'repair fuel leak',
#  '*83714 FUEL LEAK',
#  '*72925 STARTER WILL NOT DISENGAGE',
#  '78596 Electrical issues/Breakdown',
#  'SNOW BLOWER TRK/MTD INSP-12 MONTH',
#  '*65254 RIGHT SIDE CASTOR WHEEL',
#  '*46110 DVR SIDE CASTOR WHEEL WORN OUT',
#  '18772 - TLD Service bullentin repair',
#  '23796-AUTO SEDAN INSP-12 MONTH',
#  '22234-TRUCK CARRYALL INSP-12 MONTH',
#  '18777-Repairs after inspection',
#  '19913 repairs after',
#  '19913-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*04143 AIR LEAKS FROM AROUND FITTING',
#  '65169- TRAILER MISC INSP-12 MONTH',
#  'Repair after inspection',
#  'After market request',
#  '*17570 TICKING SOUND WHEN ENGINE IS RUNN',
#  'repairs after inspection',
#  '3422-2 5 Year Certification Required',
#  '*13749 PASSENGER HEADLIGHT BURNT OUT',
#  '*12993 ALARM/KEY FOB PROGRAMMING/DIAGNOT',
#  '*12601 ALARM/KEY FOB PROGRAMMING/ DIAGON',
#  '*04143 DVR SIDE RADIO WENT INTO MAINT MO',
#  'ABS fault',
#  '57624 - repairs after',
#  'After market request',
#  'After market request',
#  'After market request',
#  '*23564 OIL CHANGE REQUIRED',
#  '19466-TRUCK CARRYALL INSP-12 MONTH',
#  '*18114 DAMAGE/REPAIR ESTIMATE',
#  "*12993 OIL CHANGE REQ'D/PAX HEADLIGHTOUT",
#  'Repairs after',
#  "*13531 DVR'S SIDE MIRROR MISSING BOLT",
#  '*23567 REPAIR CRACKED WINDSHEILD',
#  '*23018 HYDRAULIC LEAK & MISSING GREASE N',
#  '22056-MISC CONST EQPT INSP-12 MONTH',
#  '*18084 Change Oil light on',
#  '*17080 DAMAGE/REPAIR ESTIMATE',
#  '*12993 ENGINE RUNNING ROUGH/ROTTEN EGG S',
#  'TLR AAGSE INSP-12 MONTH',
#  '66216- TRAILER MISC INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  '82934 - oil low',
#  '19042-TRAILER MISC PERIODIC INSPECTION',
#  'Annual inspection',
#  '*18070 RRR REQUEST & REWIRING RADIO',
#  '*16638 SAFETY RECALL TAILGATE LATCH',
#  '*14437 SAFETY RECALL TAILGATE LATCH',
#  '*11600 LIFT GATE NOT WORKING PROPERLY',
#  '*96768 THERMOSTAT N/S ONLY BLOWING HOT',
#  '*72925 BLADES NEED TO BE SHARPENED',
#  '82991- TRAILER MISC INSP-12 MONTH',
#  '*65250 WILL NOT START',
#  '*23281 FRONT HEADLIGHTS SEALS LEAKING',
#  '22238-TRUCK CARRYALL INSP-12 MONTH',
#  '18774-TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '78852- rear right tire sidewall gash',
#  '*65702 ( PLOW 16 ) caster wheel assembly',
#  '*65702 ( PLOW 16 ) REQUIRES A WELD',
#  '*18531 OIL CHANGE REQUIRED/ VTC ERROR CO',
#  'Repairs from inspection',
#  '*17207 ON/OFF SWITCH FOR DIESEL PUMP',
#  "*16646 Maint new windsheild reg'd",
#  '12601 - Dmg est and repair',
#  '*05409 FLEX CUTTER MAIN SHAFT SHEERED',
#  'Repairs after inspection',
#  'After market request',
#  '*16650 WINTER TIRES TO BE INSTALLED',
#  '*12600 ALARM/KEY FOB PROGRAMMING/DIAGNOT',
#  '*11917 CONNECTOR FOR PLOW POSTIVE NEGATI',
#  'Repair After',
#  'ARI: MILCOT 03-53771 - Rep T-Case',
#  '*78613 FRONT CYLINDERS LEAKING',
#  '64559 Repairs after inspection',
#  'After market request',
#  '18779-TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '18775-TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '18606-TLR COMMERCIAL INSP-12 MONTH',
#  'Repairs after inspection',
#  '*18113 RRR REQUEST',
#  '17080 - Epoke Right boom arm repairs',
#  '16767-FORKLIFT EMD INSP-12 MONTH',
#  '14580 - SPV - Require cutting edges',
#  'ANTI-CORROSION PROGRAM FY 19-20',
#  'ANTI-CORROSION PROGRAM FY 19-20',
#  '*90283 Repair after inspection',
#  'TRK/LIFT PLATF ICED INSP-12 MONTH',
#  '*82682 MKT REQUIRES INSPECTION',
#  '*78582 SLASH IN RT SIDE REAR TIRE',
#  'TRUCK DUMP S/C INSP-12 MONTH',
#  'New tire',
#  '22235-TRUCK CARRYALL INSP-12 MONTH',
#  '*22224 SAFETY RECALL BLOCK HEATER WIRE',
#  '21180-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*21307 SAFETY RECALL DISABLE ENGINE BLOC',
#  '*21154 SAFETY RECALL BLOCK HEATER WIRE',
#  '*20198 SAFETY RECALL BLOCK HEATER WIRE',
#  '*20196 SAFETY RECALL BLOCK HEATER WIRE',
#  '*20106 SAFETY RECALL BLOCK HEATER WIRE',
#  'After market request',
#  '*20032 SAFETY RECALL BLOCK HEATER WIRE',
#  '*17207 DASH FAULTS DISPLAYED',
#  '06471- REPAIRS FROM INSPECTION',
#  '*65703 SWEEPER CONTROL BOX IS N/S',
#  '*46110 CASTER WHEEL ON PLOW BLADE FELL O',
#  'After market request',
#  '*22238 OIL CHANGE REQUIRED',
#  '*22102 Repairs after inspection',
#  '21891-TLR COMMERCIAL INSP-12 MONTH',
#  '18775 - TLD Service bullentin repair',
#  'Repair after inspection',
#  '*12633 FRONT LICENSE PLATE MOUNT',
#  '22102-TRUCK CARRYALL INSP-12 MONTH',
#  '18775- Repairs after insp',
#  '*19912 INSTALL BEACON LIGHT CHK UHF RADI',
#  '*18084 Tire swap',
#  '*13750 FRONT PAX HEADLIGHTS BURNT OUT',
#  '*05504 WILL NOT START NEEDS BOOST',
#  '*02419 BUSHING KEEPS COMING OUT',
#  'PLATFORM TRK MTD repairs from inspection',
#  '*16561 BEACON BULB REPLACEMENT',
#  '22236-TRUCK CARRYALL INSP-12 MONTH',
#  '22230-TRUCK CARRYALL INSP-12 MONTH',
#  '17206-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*12993 NO POWER GOING TO RADAR GUN',
#  '*11600 WHEEL OFF ITS TRACK REAR DOOR',
#  '11591 - F/F MINOR INSPECTION',
#  '*00880 RIGHT FRONT TIRE BULGING',
#  '81323 - electrical issue',
#  '79395-TRACTOR WH A/C TOW S INSP-12 MONTH',
#  '*65219 NO POWER RUNNING THUR MASTER POWE',
#  '*65249 SPLIT BEARING ON MAIN SHAFT BOLTS',
#  '*65250 WILL NOT START/TURN OVER',
#  '*65702 ( PLOW 16 ) REQUIRES A WELD',
#  '23739-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '23544 aftermarket request',
#  '20235 tire swap',
#  '*19995 SAFETY RECALL',
#  '*17945 FIRE EXT BRACKETS X 2 MOUNTED',
#  '17221- REPAIRS FROM INSPECTION',
#  'Repairs after inspection',
#  '*02418 BUSHING KEEPS COMING OUT IN LOWER',
#  'CARRIER O/SNOW SM/LD INSP-12 MONTH',
#  '68821- FORKLIFT ICED INSP-12 MONTH',
#  '57596 - steering issue',
#  'TRACTOR WH A/C TOW M INSP-12 MONTH',
#  '*65254 DRIVE CHAIN SNAPPED',
#  '18001 - Repairs after inspection',
#  '14580-LOADER SCOOP INSP-12 MONTH',
#  'Electrical faults',
#  '*12750 FRONT TIRES FLAT',
#  '93686 R-11 WAIVER Damage Citerne',
#  '64961 Repairs after inspection',
#  '*23739 SWITCH CAP OFF OF OLD AMMO TRUCK',
#  '*23563 SAFETY RECALL BLOCK HEATER WIRE',
#  '22101 AFTERMARKET REQUEST',
#  '*21630 RED 4 Brakes Repairs after',
#  '*20194 SAFETY RECALL BLOCK HEATER WIRE',
#  '*20092 SAFETY RECALL BLOCK HEATER WIRE',
#  '*20033 SAFETY RECALL BLOCK HEATER WIRE',
#  '18070 AFTERMARKET REQUEST',
#  '17596 AFTERMARKET REQUEST',
#  '17212 AFTERMARKET REQUEST',
#  '14437 AFTERMARKET REQUEST',
#  '13747 Repairs after inspection',
#  "*11715 EMO OUT INSPECTION REQ'D",
#  '*11603 ESTIMATE FOR DAMAGE AND REPAIR',
#  '*01606 BROKEN KEY AND PART OF KEY IN IGN',
#  '14214 Repairs After inspection',
#  '14214 Semi-annual inspection',
#  '68504 - Horn N/S',
#  '*78596 DEAD BATTERY',
#  '*21292 INSTALL WINTER TIRES',
#  '18774 - TLD Service bullentin repair',
#  '*13750 PRINTER IN CAB N/S NO POWER',
#  '13747 Close proximity Inspection',
#  '*03346 BATTERIES NEED REPLACING',
#  '78596 Repairs after inspection',
#  '82924-Repair Shifter',
#  '*25202 EMO IN INSP REQUIRED',
#  '23733-TRUCK PANEL OVER 1T  INSP-12 MONTH',
#  '21298 - Repairs after Inspection',
#  '18779 - make tool box',
#  '*18775 LOOSE IGNITION KEYS SPINS',
#  '*19689 REQUIRES NEW TIRES TO BE MOUNTED',
#  '18228-VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '*17221 MOLDING CAME OFF',
#  '*17218 REPAIRS FROM INSPECTION',
#  '*13061 RIGHT SHOE ON BLADE CAME OFF',
#  '*13060 NO POWER TO CONTROLS FOR SANDER',
#  '*12600 NO POWER GOING TO RADAR GUN',
#  '[01241]-Repairs after inspection',
#  '*96768 REGEN SYSTEM NOT WORKING',
#  '*78582 ANTI-FREEZE LEAK IN FRONT ENGINE',
#  "*78613 AIR DOESN'T STAY IN SEAT",
#  '*78612 CB RADIO N/S',
#  '82921 - repairs after insp',
#  '*23568 WINTER TIRES, SENSORS & RIMS',
#  '*23567 WINTER TIRES, SENSOR, RIMS',
#  '*21295 PURCHASE & MOUNT WINTER TIRES, RI',
#  '12601 replace battery terminal',
#  '05199 REPLACE BATTERY',
#  '*02418 BUSHING CAME OUT IN BUCKET ARM',
#  '*96768 REGEN SYSTEM NOT WORKING',
#  '65181- Polaris Ranger RRR',
#  '*46110 HEADLIGHTS N/S',
#  '*22973 SAFETY RECALL BLOCK HEATER WIRE',
#  '18775 - ignition not working',
#  '*19933 SWITCH RADIO',
#  '13751 Repairs after inspection',
#  '13751 Close proximity inspection',
#  '13750 Repairs after inspection',
#  '13750 Close proximity inspection',
#  '*12601 WOBBLE IN FRONT END ABOVE 50 KM/H',
#  '*05850 MASTER POWER SWITCH IS SEIZED',
#  '[01241]-REFUELLER VEHICLE INSPECTION',
#  '*78582 ACCELERATOR PTO BLOWER HAS A SHOR',
#  '57624 - exhaust bracket broken',
#  '*20194 OIL CHANGE REQUIRED',
#  '*20106 OIL CHANGE REQUIRED',
#  '*20106 RADIO IN TRUCK HAS SHORT IN IT',
#  '*17214 VECH REQUIRES OIL CHANGE',
#  '*12601 WOBBLE IN FRONT END ABOVE 50 KM/H',
#  '*05850 REAR DOOR STICKING/ HARD TO OPEN',
#  '*23733 TIRE CHANGEOVER',
#  '*13061 PAX SIDE WIPER BLADE',
#  '*12601 MP CRUISER WILL NOT START',
#  '*11917 POWER DRAW ON BATTERY, NEEDS TO B',
#  "*11591 DVR'S SIDE ROLL-UP COMPARTMENT",
#  '*65251 RIGHT SIDE CHAIN CASE SEAL N/S',
#  'buckle inspection',
#  'buckle inspection',
#  '*21296 MOUNT WINTER TIRES ( NOT ON RIMS)',
#  '*20033 MOUNT WINTER TIRES ( NOT ON RIMS',
#  '*18085 REQUIRES NEW TIRES TO BE MOUNTED',
#  '*17207 SAFETY PIN MISSING ON PLOW',
#  '*17080 LEAK IN FRONT LEFT, UNKNOWN ORGIN',
#  'driver deffect for wiper',
#  '*12601 no start',
#  '*04143 no water pressure',
#  '*00879 Hydraulic system needs flushing',
#  '*00879 Front right wheel N/S',
#  "*29271 ENGINE WON'T START, BATTERY GOOD",
#  '*99995 EMO OUT INSP REQUIRED',
#  '*99992 EMO OUT INSP REQUIRED',
#  'Repairs',
#  '*84724 COLLISION DAMAGE ESTIMATE',
#  '*62026 EMO OUT INSP REQUIRED',
#  '72925 - Battery N/S',
#  '*13531 Quarts lights not turning on.',
#  'TRACTOR WH AGRIC INSP-12 MONTH',
#  '*72980 EMO OUT INSP REQUIRED',
#  '*72978 EMO OUT INSP REQUIRED',
#  '*72977 EMO OUT INSP REQUIRED',
#  "*78613 Milky look to hydraulic's",
#  '82922 - Replace batteries',
#  "*65249 DVR'S SIDE BROOM ADJUSTOR IS N/S",
#  '*65250 CHAIN IS N/S',
#  '*65702 Engine light on',
#  'repairs from inspection',
#  '22103-MISC S/P & CARGO VEH INSP-12 MONTH',
#  '17213-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  '[13751] REFUELLER B620 CERTIFICATION',
#  '[13750] REFUELLER B620 CERTIFICATION',
#  'VEHICLE ALL TERRAIN INSP-12 MONTH',
#  '12911- TLR AAGSE INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  'SNOW BLOWER TRK/MTD Repairs after inspec',
#  'TRACTOR WH A/C TOW M INSP-12 MONTH',
#  '*93686 EMO IN INSPECTION',
#  '93686 EMO in repairs',
#  '81323 - anti ice not working',
#  '65249--Sweeper checks running repairs',
#  '*93686 EMO IN INSPECTION',
#  '*21295 WINTER TIRES TO BE MOUNTED',
#  '18773 - park brake not holding',
#  '*11917 PLOUGH SHOE BUSTED',
#  '*65251 GASH IN TIRE',
#  '*65250 POWER ISSUE',
#  '*48659 SPREADER NOT WORKING',
#  '*14580 UNUSUAL SOUND FR ENGINE',
#  '*11591 EMERGENCY LIGHTS NOT WORKING',
#  '*12750 FRONT LEFT TIRE FLAT',
#  '75919 - Engine noise',
#  '*65250 BROOM WILL NOT STAY IN POSTION',
#  '*46110 SMALL COOLANT LEAK',
#  'requires tires',
#  '22236 winter tires',
#  '22101-TRUCK CARRYALL INSP-12 MONTH',
#  '06471-BUS UP TO 28 PAX 6 MON INSPECTION',
#  '00969- repair brakes',
#  '*12633 CHECK ENGINE LIGHT ON/ CHECK REPA',
#  '*17989 RADIO, BEACON LIGHT, REAR BACK-UP',
#  '22103-Repairs from insp',
#  '19012-repairs from inspection',
#  "*23563 BIG SCRATCH BY DVR'S SIDE REAR TI",
#  '*22527 VECH NEEDS NEW ALL SEASON & WINTE',
#  '*19012 REQUIRES NEW TIRES TO BE MOUNTED',
#  '18084-repairs from inspection',
#  '17221-TRUCK PANEL OVER 1T INSP-12 MONTH',
#  '*13579 BELTS LOOSE TO WATER PUMP & ALT',
#  '*11602 EMO OUT INSP REQUIRED',
#  '*02787 PROPANE F/L REQUIRES NEW BATTERY',
#  '*93276 RUSTED VALVE STEM WHICH BROKE OFF',
#  '*17997 EMO OUT INSP REQUIRED',
#  'PRI B Warning Label - Vignette Securité',
#  'TLR AAGSE INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  'TLR AAGSE INSP-12 MONTH',
#  '65249 Sweeper checks',
#  'TRK TPT/UTIL TO 7T INSP-12 MONTH',
#  '*19688 OIL CHANGE REQUIRED/ CONSTANTLY L',
#  '3422-2 Quarterly Inspection',
#  '82934 - repairs after inspection',
#  '57596 - park brake cable n/s',
#  'Mobile Crane Certification [24268]',
#  '*23544 OIL CHANGE REQUIRED',
#  '*21292 OIL CHANGE REQUIRED',
#  '*20194 repairs after inspection',
#  'repairs after inspection',
#  '*18114 SAFETY RECALL TAILGATE LATCH',
#  '18114- Repairs from inspection',
#  '*17564 WINTER TIRE INSTALLATION',
#  '*16635 VEHICLE REQUIRES NEW TIRES ( BALD',
#  'Repair after inspection',
#  'Repair after inspection',
#  '82923 - Repairs',
#  '*64961 CRACK SIDE WALL OF PAX SIDE TIRE',
#  '*65702 CHECK ENGINE & STOP ENGINE LIGHT',
#  'PLATFORM TRK MTD INSP-12 MONTH',
#  '*25050 EMO IN INSPECTION REQUIRED',
#  '23643-MISC CONST EQPT INSP-12 MONTH',
#  '22267-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '*22237 WINTER TIRES MOUNTED',
#  '*22233 VEHICLE NEEDS OIL CHANGE',
#  '21307-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '20245-TRAILER MISC INSP-12 MONTH',
#  '*20194 WHEEL ALIGNEMENT NEEDED',
#  '*18114 OIL CHANGE LIGHT COMING ON',
#  '18001-LOADER SCOOP INSP-12 MONTH',
#  '17218-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '17214-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '17204-TRK CARGO TO 3 1/2 T INSP-12 MONT',
#  '13579-LOADER SKID STEER INSP-12 MONTH',
#  '*11917 SALT SPREADER FELL APART, MISSING',
#  '*01500 BRAKE REPAIR',
#  '96680- TLR AAGSE INSP-12 MONTH',
#  '66194- TRAILER MISC INSP-12 MONTH',
#  '66196- TRAILER MISC INSP-12 MONTH',
#  'TRK/LIFT PLATF ICED INSP-12 MONTH',
#  '105MM HOWITZER TOW ARMEMENT INSP',
#  'TRAILER MISC INSP-12 MONTH',
#  'VEHICLE ALL TERRAIN INSP-12 MONTH',
#  'TRAILER MISC INSP-12 MONTH',
#  '57572 - repairs after insp',
#  '42811 Repairs after inspection',
#  '*16286 EMO IN INSPECTION REQUIRED',
#  '*23765 CHECK ENGINE LIGHT ON/ SHAKING',
#  '*22237 NEW ALL SEASON TIRES',
#  '*17203 DIFF STUCK',
#  '*14480 INSPECTION AFTER REPAIRS DOWNTOWN',
#  '*14196 OIL CHANGE NEEDED',
#  '11887 - EMO out inspection',
#  '*04143 CENTER WIPER BLADE NEEDS REPLACIN',
#  'TRUCK VAN OSCAR repairs from inspection',
#  '*13531 WATER LEAKING INTO CAB',
#  '23565-TRK CARGO TO 3 1/2 T INSP-12 MONTH',
#  '23563-cap swap from 06278',
#  '17214-Replace Tires',
#  'space cap to be installed on 23563',
#  '23591 - RAI - Battery',
#  '23590-Repairs from inspection',
#  '23563-repairs from inspection',
#  '23377-Repairs After Insp',
#  '*21299 VECHILE NEEDS OIL CHANGE',
#  "*14437 DVR'S SIDE FRONT TIRE FLAT",
#  '04145 Repairs after inspection',
#  '*01241 LEAK IN LOW PRESSURE HOSE LEVER',
#  '*78596 MULTIPLE DEFECTS',
#  '[93688]-REFUELLER VEHICLE INSPECTION',
#  '*25052 EMO IN INSPECTION REQUIRED',
#  '*25051 EMO IN INSPECTION REQUIRED',
#  '*13749 HIGH PRESSURE HOSE SENSOR BROKEN',
#  '12600-AUTO SEDAN INSP-06 MONTH',
#  '12600-repairs from inspection',
#  '*04143 BRACKET BROKEN AND MISSING',
#  '*90283 EMO IN INSPECTION REQUIRED',
#  '*90352 EMO IN INSPECTION REQUIRED',
#  '18461 - Repairs After Inspection',
#  '75919 - Repairs aftfer inspection',
#  ...]
